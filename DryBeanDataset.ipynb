# %% [markdown]
# # Dry Bean Dataset Dataset Project EDA Part

# %% [markdown]
# #### Task Given by instructor Aman Choudhary
# 1 Import the dataset
# https://archive.ics.uci.edu/dataset/602/dry+bean+dataset
#
# 2. Do proper EDA(analysis) of your dataset and create a report
#
# 3. Then perform necessary preprocessing steps

# %% [markdown]
# # Information
# Seven different types of dry beans were used in this research, taking into account the features such as form, shape, type, and structure by the market situation. A computer vision system was developed to distinguish seven different registered varieties of dry beans with similar features in order to obtain uniform seed classification. For the classification model, images of 13,611 grains of 7 different registered dry beans were taken with a high-resolution camera. Bean images obtained by computer vision system were subjected to segmentation and feature extraction stages, and a total of 16 features; 12 dimensions and 4 shape forms, were obtained from the grains.

# %% [markdown]
# ## 2. DATA COLLECTION AND UNDERSTANDING
#
# # Additional Information
#
# 1.) Area (A): The area of a bean zone and the number of pixels within its boundaries.
#
# 2.) Perimeter (P): Bean circumference is defined as the length of its border.
#
# 3.) Major axis length (L): The distance between the ends of the longest line that can be drawn from a bean.
#
# 4.) Minor axis length (l): The longest line that can be drawn from the bean while standing perpendicular to the main axis.
#
# 5.) Aspect ratio (K): Defines the relationship between L and l.
#
# 6.) Eccentricity (Ec): Eccentricity of the ellipse having the same moments as the region.
#
# 7.) Convex area (C): Number of pixels in the smallest convex polygon that can contain the area of a bean seed.
#
# 8.) Equivalent diameter (Ed): The diameter of a circle having the same area as a bean seed area.
#
# 9.) Extent (Ex): The ratio of the pixels in the bounding box to the bean area.
#
# 10.)Solidity (S): Also known as convexity. The ratio of the pixels in the convex shell to those found in beans.
#
# 11.)Roundness (R): Calculated with the following formula: (4piA)/(P^2)
#
# 12.)Compactness (CO): Measures the roundness of an object: Ed/L
#
# 13.)ShapeFactor1 (SF1)
#
# 14.)ShapeFactor2 (SF2)
#
# 15.)ShapeFactor3 (SF3)
#
# 16.)ShapeFactor4 (SF4)
#
# 17.)Class (Seker, Barbunya, Bombay, Cali, Dermosan, Horoz and Sira)

# %% [markdown]
# ## 3. DATA EXPLORATION
#
# * In this step, we will apply Exploratory Data Analysis (EDA) to extract insights from the data set to know which features have contributed more in predicting Forest fire by performing Data Analysis using Pandas and Data visualization using Matplotlib & Seaborn. It is always a good practice to understand the data first and try to gather as many insights from it.
#
#
# Below are tasks to be performed in EDA:
#
# **1. Importing Libraries**
#
#
# **2. Data Cleaning for EDA Report**
#
# **3. Exploratory Data Analysis (EDA) on all Features**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import json
from warnings import filterwarnings
filterwarnings('ignore')

# %%
import numpy as np

# %%
# Create Dataframe and Read the dataset using Pandas
dataset = pd.read_excel('D:\Developement of api of Aws\Detection Data\DryBeanDataset\Dry_Bean_Dataset.xlsx', header=1)
dataset.head()
# Out:
#    28395  610.2909999999998  208.17811670852728  173.88874704163598  \
# 0  28734            638.018          200.524796          182.734419
# 1  29380            624.110          212.826130          175.931143
# 2  30008            645.884          210.557999          182.516516
# 3  30140            620.134          201.847882          190.279279
# 4  30279            634.927          212.560556          181.510182
#
#    1.1971914241160242  0.5498121871383472  28715  190.1410972745107  \
# 0            1.097356            0.411785  29172         191.272750
# 1            1.209713            0.562727  29690         193.410904
# 2            1.153638            0.498616  30724         195.467062
# 3            1.060798            0.333680  30417         195.896503
# 4            1.171067            0.520401  30600         196.347702
#
#    0.7639225181598063  0.9888559986069998  0.9580271262501276  \
# 0            0.783968            0.984986            0.887034
# ...

# %%
dataset
# Out:
#        28395  610.2909999999998  208.17811670852728  173.88874704163598  \
# 0      28734            638.018          200.524796          182.734419
# 1      29380            624.110          212.826130          175.931143
# 2      30008            645.884          210.557999          182.516516
# 3      30140            620.134          201.847882          190.279279
# 4      30279            634.927          212.560556          181.510182
# ...      ...                ...                 ...                 ...
# 13605  42097            759.696          288.721612          185.944705
# 13606  42101            757.499          281.576392          190.713136
# 13607  42139            759.321          281.539928          191.187979
# 13608  42147            763.779          283.382636          190.275731
# 13609  42159            772.237          295.142741          182.204716
#
#        1.1971914241160242  0.5498121871383472  28715  190.1410972745107  \
# ...

# %%
# Convert Dataframe into Dictionary as MongoDB stores data in records/documents
data = dataset.to_dict(orient = 'records')

# %%
json_data = dataset.to_json(orient='records')

# %%
parsed_json_data = json.loads(json_data)

# %%
from pymongo.mongo_client import MongoClient
uri = "mongodb+srv://amankumar:amankumar@cluster0.oliwjpa.mongodb.net/?retryWrites=true&w=majority"
# Create a new client and connect to the server
client = MongoClient(uri)

mongo_db = client["database_name"]
column = mongo_db['table']

column.insert_many(parsed_json_data)

# %%
dataset
# Out:
#        28395  610.2909999999998  208.17811670852728  173.88874704163598  \
# 0      28734            638.018          200.524796          182.734419
# 1      29380            624.110          212.826130          175.931143
# 2      30008            645.884          210.557999          182.516516
# 3      30140            620.134          201.847882          190.279279
# 4      30279            634.927          212.560556          181.510182
# ...      ...                ...                 ...                 ...
# 13605  42097            759.696          288.721612          185.944705
# 13606  42101            757.499          281.576392          190.713136
# 13607  42139            759.321          281.539928          191.187979
# 13608  42147            763.779          283.382636          190.275731
# 13609  42159            772.237          295.142741          182.204716
#
#        1.1971914241160242  0.5498121871383472  28715  190.1410972745107  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13608 entries, 0 to 13607
# Data columns (total 18 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   nan     13608 non-null  int64
#  1   nan     13608 non-null  float64
#  2   nan     13608 non-null  float64
#  3   nan     13608 non-null  float64
#  4   nan     13608 non-null  float64
#  5   nan     13608 non-null  float64
#  6   nan     13608 non-null  int64
#  7   nan     13608 non-null  float64
#  8   nan     13608 non-null  float64
#  9   nan     13608 non-null  float64
#  10  nan     13608 non-null  float64
#  11  nan     13608 non-null  float64
#  12  nan     13608 non-null  float64
#  13  nan     13608 non-null  float64
#  14  nan     13608 non-null  float64
#  15  nan     13608 non-null  float64
#  16  SEKER   13608 non-null  object
#  17  Region  13608 non-null  int32
# dtypes: float64(14), int32(1), int64(2), object(1)
# memory usage: 1.8+ MB

# %% [markdown]
# ##  Data Cleaning

# %%
# Columns which has null values
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, SEKER, Region]
# Index: []

# %% [markdown]
# **Add new column with region**

# %%
df.loc[:122,'Region']=1
df.loc[122:,'Region']=2
df[['Region']] = df[['Region']].astype(int)

# %%
df.isnull().sum()
# Out:
# NaN       0
# NaN       0
# NaN       0
# NaN       0
# NaN       0
# NaN       0
# NaN       0
# NaN       0
# NaN       0
# NaN       0
# NaN       0
# NaN       0
# NaN       0
# NaN       0
# NaN       0
# NaN       0
# SEKER     0
# Region    0
# dtype: int64

# %%
# Remove null or na values rows
df =df.dropna().reset_index(drop=True) 
df.shape
# Out:
# (13608, 18)

# %%
# Column which has string
df.iloc[[423]]
# Out:
#        NaN      NaN         NaN         NaN       NaN       NaN    NaN  \
# 423  35901  684.781  238.026453  192.274009  1.237954  0.589478  36216
#
#             NaN       NaN       NaN       NaN       NaN      NaN       NaN  \
# 423  213.800311  0.778341  0.991302  0.962084  0.898221  0.00663  0.002662
#
#           NaN       NaN  SEKER  Region
# 423  0.806801  0.998782  SEKER       2

# %%
#remove 122th column
df= df.drop(423).reset_index(drop=True)

# %% [markdown]
# **Some column names were misspaced so we can fix it**

# %%
# List out column names to check 
df.columns
# Out:
# Index([     nan,      nan,      nan,      nan,      nan,      nan,      nan,
#             nan,      nan,      nan,      nan,      nan,      nan,      nan,
#             nan,      nan,  'SEKER', 'Region'],
#       dtype='object')

# %% [markdown]
# Looks like the values were misspaced so we can use **str.strip()** method

# %%
# Spaces were fixed in the column names
df.columns = df.columns.str.strip()
df.columns
# Out:
# Index([     nan,      nan,      nan,      nan,      nan,      nan,      nan,
#             nan,      nan,      nan,      nan,      nan,      nan,      nan,
#             nan,      nan,  'SEKER', 'Region'],
#       dtype='object')

# %%
# Final datatypes check
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13607 entries, 0 to 13606
# Data columns (total 18 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   nan     13607 non-null  int64
#  1   nan     13607 non-null  float64
#  2   nan     13607 non-null  float64
#  3   nan     13607 non-null  float64
#  4   nan     13607 non-null  float64
#  5   nan     13607 non-null  float64
#  6   nan     13607 non-null  int64
#  7   nan     13607 non-null  float64
#  8   nan     13607 non-null  float64
#  9   nan     13607 non-null  float64
#  10  nan     13607 non-null  float64
#  11  nan     13607 non-null  float64
#  12  nan     13607 non-null  float64
#  13  nan     13607 non-null  float64
#  14  nan     13607 non-null  float64
#  15  nan     13607 non-null  float64
#  16  SEKER   13607 non-null  object
#  17  Region  13607 non-null  int32
# dtypes: float64(14), int32(1), int64(2), object(1)
# memory usage: 1.8+ MB

# %%
df.describe().T
# Out:
#           count          mean           std           min           25%  \
# NaN     13607.0  53054.057323  29326.425374  20420.000000  36341.500000
# NaN     13607.0    855.341068    214.294195    524.736000    703.578000
# NaN     13607.0    320.169300     85.691591    183.601165    253.324416
# NaN     13607.0    202.275080     44.975777    122.512653    175.848170
# NaN     13607.0      1.583352      0.246631      1.024868      1.432362
# NaN     13607.0      0.750951      0.091957      0.218951      0.715954
# NaN     13607.0  53774.094510  29777.260714  20684.000000  36719.000000
# NaN     13607.0    253.078048     59.180089    161.243764    215.107961
# NaN     13607.0      0.749727      0.049092      0.555315      0.718629
# NaN     13607.0      0.987142      0.004661      0.919246      0.985670
# NaN     13607.0      0.873255      0.059508      0.489618      0.832052
# NaN     13607.0      0.799832      0.061694      0.640577      0.762444
# ...

# %% [markdown]
# **Data Cleaning in target variable**

# %%
# Check Unique values of target variable
dataset.value_counts()
# Out:
# 28395   610.2909999999998  208.17811670852728  173.88874704163598  1.1971914241160242  0.5498121871383472  28715   190.1410972745107  0.7639225181598063  0.9888559986069998  0.9580271262501276  0.9133577547957626  0.007331506135183212  0.00314728916733569  0.8342223882455564  0.9987238890131684  SEKER
# 42156   815.245            335.198243          160.936938          2.082792            0.877200            42586   231.677980         0.834046            0.989903            0.797064            0.691167            0.007951              0.001119             0.477712            0.994975            HOROZ       2
# 46777   845.203            349.187769          171.167126          2.040040            0.871618            47247   244.045746         0.821413            0.990052            0.822849            0.698895            0.007465              0.001099             0.488455            0.996467            HOROZ       2
# ...

# %%
#### Region 1

# %%
df[:423]
# Out:
#        NaN      NaN         NaN         NaN       NaN       NaN    NaN  \
# 0    28734  638.018  200.524796  182.734419  1.097356  0.411785  29172
# 1    29380  624.110  212.826130  175.931143  1.209713  0.562727  29690
# 2    30008  645.884  210.557999  182.516516  1.153638  0.498616  30724
# 3    30140  620.134  201.847882  190.279279  1.060798  0.333680  30417
# 4    30279  634.927  212.560556  181.510182  1.171067  0.520401  30600
# ..     ...      ...         ...         ...       ...       ...    ...
# 418  35842  679.664  232.110749  196.733453  1.179823  0.530661  36127
# 419  35845  683.888  229.295297  199.457906  1.149592  0.493275  36169
# 420  35853  678.636  230.972174  197.894795  1.167146  0.515664  36172
# 421  35864  681.390  231.339332  197.813740  1.169481  0.518495  36158
# 422  35872  684.086  232.552030  196.591746  1.182919  0.534186  36214
#
#             NaN       NaN       NaN       NaN       NaN       NaN       NaN  \
# ...

# %% [markdown]
# #### Region 2

# %%
df[423:]
# Out:
#          NaN      NaN         NaN         NaN       NaN       NaN    NaN  \
# 423    35915  685.086  238.637070  191.837438  1.243955  0.594781  36222
# 424    35923  684.665  229.981830  199.115359  1.155018  0.500412  36239
# 425    35932  688.727  242.496230  188.791162  1.284468  0.627604  36273
# 426    35954  710.093  251.660769  182.014822  1.382639  0.690581  36380
# 427    35955  683.377  242.604317  188.873692  1.284479  0.627613  36232
# ...      ...      ...         ...         ...       ...       ...    ...
# 13602  42097  759.696  288.721612  185.944705  1.552728  0.765002  42508
# 13603  42101  757.499  281.576392  190.713136  1.476439  0.735702  42494
# 13604  42139  759.321  281.539928  191.187979  1.472582  0.734065  42569
# 13605  42147  763.779  283.382636  190.275731  1.489326  0.741055  42667
# 13606  42159  772.237  295.142741  182.204716  1.619841  0.786693  42600
#
#               NaN       NaN       NaN       NaN       NaN       NaN       NaN  \
# ...

# %% [markdown]
# ###  Exploratory Data Analysis (EDA)

# %%
dataset
# Out:
#        28395  610.2909999999998  208.17811670852728  173.88874704163598  \
# 0      28734            638.018          200.524796          182.734419
# 1      29380            624.110          212.826130          175.931143
# 2      30008            645.884          210.557999          182.516516
# 3      30140            620.134          201.847882          190.279279
# 4      30279            634.927          212.560556          181.510182
# ...      ...                ...                 ...                 ...
# 13605  42097            759.696          288.721612          185.944705
# 13606  42101            757.499          281.576392          190.713136
# 13607  42139            759.321          281.539928          191.187979
# 13608  42147            763.779          283.382636          190.275731
# 13609  42159            772.237          295.142741          182.204716
#
#        1.1971914241160242  0.5498121871383472  28715  190.1410972745107  \
# ...

# %% [markdown]
# **Visualization of Distribution**

# %%
# PLot density plot for all features
plt.style.use('seaborn')
dataset.hist(bins=50, figsize=(20,15), ec = 'b')
plt.show()

# %%
# Percentage for PieChart
percentage = dataset.value_counts(normalize=True)*100
percentage
# Out:
# 28395   610.2909999999998  208.17811670852728  173.88874704163598  1.1971914241160242  0.5498121871383472  28715   190.1410972745107  0.7639225181598063  0.9888559986069998  0.9580271262501276  0.9133577547957626  0.007331506135183212  0.00314728916733569  0.8342223882455564  0.9987238890131684  SEKER
# 42156   815.245            335.198243          160.936938          2.082792            0.877200            42586   231.677980         0.834046            0.989903            0.797064            0.691167            0.007951              0.001119             0.477712            0.994975            HOROZ       0.014695
# 46777   845.203            349.187769          171.167126          2.040040            0.871618            47247   244.045746         0.821413            0.990052            0.822849            0.698895            0.007465              0.001099             0.488455            0.996467            HOROZ       0.014695
# ...

# %% [markdown]
# **Checking Multicollinearity**

# %%
import matplotlib.pyplot as plt
import seaborn as sns 
plt.figure(figsize=(20,15))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Canadian DryBeanDataset (DBD) System
# This column can be considered for Regression problem

# %%
#Boxplot
ax = sns.boxplot(dataset,color= 'yellow')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set()
plt.figure(figsize=(25, 10))
bar_plot = sns.barplot(data=dataset)  # Assuming data_features is your DataFrame or dataset

# Rotate the x-axis labels diagonally
bar_plot.set_xticklabels(bar_plot.get_xticklabels(), rotation=45, ha='right')
# Add labels and title
bar_plot.set_xlabel('X-Axis Label')
bar_plot.set_ylabel('Y-Axis Label')

plt.show()

# %% [markdown]
# ###  Exploratory Data Analysis (EDA) on all Features

# %%
df.columns
# Out:
# Index([     nan,      nan,      nan,      nan,      nan,      nan,      nan,
#             nan,      nan,      nan,      nan,      nan,      nan,      nan,
#             nan,      nan,  'SEKER', 'Region'],
#       dtype='object')

# %%
iris = sns.load_dataset('iris')

# %%
sns.scatterplot(x = iris.sepal_length , y = iris.sepal_width)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.scatterplot(x = iris.sepal_length , y = iris.petal_length)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.displot(iris['sepal_length'])

# %%
df
# Out:
#          NaN      NaN         NaN         NaN       NaN       NaN    NaN  \
# 0      28734  638.018  200.524796  182.734419  1.097356  0.411785  29172
# 1      29380  624.110  212.826130  175.931143  1.209713  0.562727  29690
# 2      30008  645.884  210.557999  182.516516  1.153638  0.498616  30724
# 3      30140  620.134  201.847882  190.279279  1.060798  0.333680  30417
# 4      30279  634.927  212.560556  181.510182  1.171067  0.520401  30600
# ...      ...      ...         ...         ...       ...       ...    ...
# 13602  42097  759.696  288.721612  185.944705  1.552728  0.765002  42508
# 13603  42101  757.499  281.576392  190.713136  1.476439  0.735702  42494
# 13604  42139  759.321  281.539928  191.187979  1.472582  0.734065  42569
# 13605  42147  763.779  283.382636  190.275731  1.489326  0.741055  42667
# 13606  42159  772.237  295.142741  182.204716  1.619841  0.786693  42600
#
#               NaN       NaN       NaN       NaN       NaN       NaN       NaN  \
# ...

# %%
x=np.linspace(0,13607,13607)

# %%
x
# Out:
# array([0.00000000e+00, 1.00007350e+00, 2.00014699e+00, ...,
#        1.36049999e+04, 1.36059999e+04, 1.36070000e+04])

# %%
y=np.sin(x)

# %%
y
# Out:
# array([ 0.        ,  0.84151069,  0.90923625, ...,  0.94510954,
#         0.23561972, -0.69052693])

# %%
plt.plot(x,y)

# %%
x = np.random.rand(50)
y = np.random.rand(50)
plt.scatter(x,y)

# %%
colours =np.random.rand(50)
sizes = 500 *np.random.rand(50)
plt.scatter(x,y,c =colours ,s=sizes)

# %% [markdown]
# ### 3d Graph Visualization

# %%
x = np.random.rand(150)
y = np.random.rand(150)
z = np.random.rand(150)

fig = plt.figure()
ax = fig.add_subplot(projection = '3d')
ax.scatter(x,y,z)
plt.show()

# %% [markdown]
# # End
